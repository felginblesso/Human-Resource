# %% [markdown]
# # Library Installing

# %%
# Pandas package

# !pip install pandas
import pandas as pd

# Missingno package installation

# !pip install missingno
import missingno as msno

# Matplotlib package installation

# !pip install matplotlib
import matplotlib.pyplot as plt

# Seaborn package installation

# !pip install seaborn
import seaborn as sns

# Numpy Installation

# !pip install numpy
import numpy as np

# %% [markdown]
# # Dataset

# %%
# Read the dataset

df_tamilnadu = pd.read_csv("/content/DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv", encoding="latin1")
df_kerala = pd.read_csv("/content/DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv", encoding="latin1")
df_goa = pd.read_csv("/content/DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv", encoding="latin1")
df_puducherry = pd.read_csv("/content/DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv", encoding="latin1")
df_himachal = pd.read_csv("/content/DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv", encoding="latin1")
df_uttarkhand = pd.read_csv("/content/DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv", encoding="latin1")
df_uttarpradesh = pd.read_csv("/content/DDW_B18st_0900_NIC_FINAL_STATE_UTTAR_PRADESH-2011.csv", encoding="latin1")
df_bihar = pd.read_csv("/content/DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv", encoding="latin1")
df_sikkim = pd.read_csv("/content/DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv", encoding="latin1")
df_assam = pd.read_csv("/content/DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv", encoding="latin1")
df_odisha = pd.read_csv("/content/DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv", encoding="latin1")
df_karnataka = pd.read_csv("/content/DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv", encoding="latin1")
df_maharashtra = pd.read_csv("/content/DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv", encoding="latin1")
df_gujarat = pd.read_csv("/content/DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv", encoding="latin1")
df_jharkhand = pd.read_csv("/content/DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv", encoding="latin1")
df_tripura = pd.read_csv("/content/DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv", encoding="latin1")
df_delhi = pd.read_csv("/content/DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv", encoding="latin1")
df_westbangal = pd.read_csv("/content/DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv", encoding="latin1")
df_mizoram = pd.read_csv("/content/DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv", encoding="latin1")
df_manipur = pd.read_csv("/content/DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv", encoding="latin1")
df_arunachalpradesh = pd.read_csv("/content/DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv", encoding="latin1")
df_rajesthan = pd.read_csv("/content/DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv", encoding="latin1")

# %% [markdown]
# Merge the dataset

# %%
import glob

# Path where all CSV files are stored
file_path = "/content/*.csv"

# Get a list of all CSV files
csv_files = glob.glob(file_path)

# Read all CSV files into a list of DataFrames
dfs = [pd.read_csv(file, encoding="latin1") for file in csv_files]

# Merge all DataFrames into a single DataFrame
df = pd.concat(dfs, ignore_index=True)

# Display merged DataFrame info
print(df.info())

# Save the merged file if needed
#df.to_csv("merged_workers_data.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195145 entries, 0 to 195144
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   State Code                           195145 non-null  object
#  1   District Code                        195145 non-null  object
#  2   India/States                         195145 non-null  object
#  3   Division                             195145 non-null  object
#  4   Group                                195145 non-null  object
#  5   Class                                195145 non-null  object
#  6   NIC Name                             195145 non-null  object
#  7   Main Workers - Total -  Persons      195145 non-null  int64
#  8   Main Workers - Total - Males         195145 non-null  int64
#  9   Main Workers - Total - Females       195145 non-null  int64
#  10  Main Workers - Rural -  Persons      195145 non-null  int64
# ...

# %%
df
# Out:
#        State Code District Code           India/States Division Group  Class  \
# 0             `10          `000          STATE - BIHAR      `00  `000  `0000
# 1             `10          `000          STATE - BIHAR      `01  `000  `0000
# 2             `10          `000          STATE - BIHAR      `01  `011  `0000
# 3             `10          `000          STATE - BIHAR      `01  `011  `0111
# 4             `10          `000          STATE - BIHAR      `01  `011  `0114
# ...           ...           ...                    ...      ...   ...    ...
# 195140        `29          `584  District - Ramanagara      `99  `990  `9900
# 195141        `29          `584  District - Ramanagara      `99  `991  `0000
# 195142        `29          `584  District - Ramanagara      `99  `991  `9910
# 195143        `29          `584  District - Ramanagara      `99  `992  `0000
# 195144        `29          `584  District - Ramanagara      `99  `992  `9920
#
# ...

# %%
df.columns
# Out:
# Index(['State Code', 'District Code', 'India/States', 'Division', 'Group',
#        'Class', 'NIC Name', 'Main Workers - Total -  Persons',
#        'Main Workers - Total - Males', 'Main Workers - Total - Females',
#        'Main Workers - Rural -  Persons', 'Main Workers - Rural - Males',
#        'Main Workers - Rural - Females', 'Main Workers - Urban -  Persons',
#        'Main Workers - Urban - Males', 'Main Workers - Urban - Females',
#        'Marginal Workers - Total -  Persons',
#        'Marginal Workers - Total - Males',
#        'Marginal Workers - Total - Females',
#        'Marginal Workers - Rural -  Persons',
#        'Marginal Workers - Rural - Males',
#        'Marginal Workers - Rural - Females',
#        'Marginal Workers - Urban -  Persons',
#        'Marginal Workers - Urban - Males',
#        'Marginal Workers - Urban - Females'],
#       dtype='object')

# %% [markdown]
# #Data Pre-Processing

# %%
# Rename the column

df['District Name'] = df.pop('India/States')

# %%
df['District Name'] = df['District Name'].str.replace(r'^(STATE - |District - )', '', regex=True)

# %%
# Missing values

df.isnull().sum()
# Out:
# State Code                             0
# District Code                          0
# Division                               0
# Group                                  0
# Class                                  0
# NIC Name                               0
# Main Workers - Total -  Persons        0
# Main Workers - Total - Males           0
# Main Workers - Total - Females         0
# Main Workers - Rural -  Persons        0
# Main Workers - Rural - Males           0
# Main Workers - Rural - Females         0
# Main Workers - Urban -  Persons        0
# Main Workers - Urban - Males           0
# Main Workers - Urban - Females         0
# Marginal Workers - Total -  Persons    0
# Marginal Workers - Total - Males       0
# Marginal Workers - Total - Females     0
# Marginal Workers - Rural -  Persons    0
# Marginal Workers - Rural - Males       0
# Marginal Workers - Rural - Females     0
# Marginal Workers - Urban -  Persons    0
# Marginal Workers - Urban - Males       0
# ...

# %%
# Duplicate values

duplicates = df.duplicated()
print(duplicates.sum())  # Count of duplicate rows
# Out:
# 0

# %%
df.shape
# Out:
# (195145, 25)

# %%
# Datatype conversion

columns_to_clean = ['State Code', 'District Code', 'Division', 'Group', 'Class']

# Remove unwanted characters
df[columns_to_clean] = df[columns_to_clean].apply(lambda col: col.astype(str).str.replace(r"[^\d]", "", regex=True).str.strip())

# Convert to integer (if data is purely numeric)
df[columns_to_clean] = df[columns_to_clean].apply(pd.to_numeric, errors='coerce')

# %%
df
# Out:
#         State Code  District Code  Division  Group  Class  \
# 0               10              0         0      0      0
# 1               10              0         1      0      0
# 2               10              0         1     11      0
# 3               10              0         1     11    111
# 4               10              0         1     11    114
# ...            ...            ...       ...    ...    ...
# 195140          29            584        99    990   9900
# 195141          29            584        99    991      0
# 195142          29            584        99    991   9910
# 195143          29            584        99    992      0
# 195144          29            584        99    992   9920
#
#                                                  NIC Name  \
# 0                                                   Total
# 1       Crop and animal production, hunting and relate...
# 2                          Growing of non-perennial crops
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195145 entries, 0 to 195144
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   State Code                           195145 non-null  int64
#  1   District Code                        195145 non-null  int64
#  2   Division                             195145 non-null  int64
#  3   Group                                195145 non-null  int64
#  4   Class                                195145 non-null  int64
#  5   NIC Name                             195145 non-null  object
#  6   Main Workers - Total -  Persons      195145 non-null  int64
#  7   Main Workers - Total - Males         195145 non-null  int64
#  8   Main Workers - Total - Females       195145 non-null  int64
#  9   Main Workers - Rural -  Persons      195145 non-null  int64
#  10  Main Workers - Rural - Males         195145 non-null  int64
# ...

# %%
# Removing "total" from "NIC Name" column

#df['NIC Name'] = df['NIC Name'].str.replace('total', '', case=False, regex=True).str.strip()

df = df[~df['NIC Name'].str.contains('total', case=False, na=False)]

# %%
# Count rows where NIC Name is exactly "Blank"

blank_count = (df['NIC Name'] == 'Blank').sum()
total_count = len(df)
blank_percentage = (blank_count / total_count) * 100

print(f"Total rows            : {total_count}")
print(f'Rows with "Blank"     : {blank_count}')
print(f'Percentage of "Blank" : {blank_percentage:.2f}%')
# Out:
# Total rows            : 194651
# Rows with "Blank"     : 918
# Percentage of "Blank" : 0.47%

# %%
# Replacing the "Blank" value with "Construction of buildings"

mode_value = df.loc[df["NIC Name"] != "Blank", "NIC Name"].mode()[0]
df["NIC Name"] = df["NIC Name"].replace("Blank", mode_value)
print(f'Replaced "Blank" with mode value: {mode_value}')
# Out:
# Replaced "Blank" with mode value: Construction of buildings
# <ipython-input-16-47409e40f541>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NIC Name"] = df["NIC Name"].replace("Blank", mode_value)

# %% [markdown]
# #EDA

# %%
# Missing value visualization

msno.matrix(df)
plt.show()

# %%
# Top 10 Industries by Total Workers
plt.figure(figsize=(12,6))
top_industries = df.groupby('NIC Name')['Main Workers - Total -  Persons'].sum().nlargest(10)
top_industries.plot(kind='barh', color='teal')
plt.xlabel("Total Workers")
plt.ylabel("Industry")
plt.title("Top 10 Industries by Total Workers")
plt.gca().invert_yaxis()
plt.show()

# %%
# Selecting relevant columns
columns_to_plot = ['Main Workers - Total -  Persons', 'Marginal Workers - Total -  Persons']

# Summing up the total number of workers in each category
worker_counts = df[columns_to_plot].sum()

# Creating the bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x=worker_counts.index, y=worker_counts.values, palette="viridis")

# Customizing the plot
plt.title("Distribution of Main Workers vs. Marginal Workers")
plt.ylabel("Total Number of Workers")
plt.xlabel("Worker Category")
plt.xticks(rotation=0)  # Keep labels horizontal

# Show the plot
plt.show()
# Out:
# <ipython-input-19-78ebb643bafe>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=worker_counts.index, y=worker_counts.values, palette="viridis")

# %%
# Selecting relevant columns (Main workers)
columns_to_plot = ['Main Workers - Rural -  Persons', 'Main Workers - Urban -  Persons']

# Summing up the total number of workers in each category
worker_counts = df[columns_to_plot].sum()

# Creating the bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x=worker_counts.index, y=worker_counts.values, palette="viridis")

# Customizing the plot
plt.title("Distribution of (Main) Rural Workers vs. Urban Workers")
plt.ylabel("Total Number of Workers")
plt.xlabel("Worker Category")
plt.xticks(rotation=0)  # Keep labels horizontal

# Show the plot
plt.show()
# Out:
# <ipython-input-20-6e3f60c399b6>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=worker_counts.index, y=worker_counts.values, palette="viridis")

# %%
# Selecting relevant columns (Marginal workers)
columns_to_plot = ['Marginal Workers - Rural -  Persons', 'Marginal Workers - Urban -  Persons']

# Summing up the total number of workers in each category
worker_counts = df[columns_to_plot].sum()

# Creating the bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x=worker_counts.index, y=worker_counts.values, palette="viridis")

# Customizing the plot
plt.title("Distribution of (Marginal) Rural Workers vs. Urban Workers")
plt.ylabel("Total Number of Workers")
plt.xlabel("Worker Category")
plt.xticks(rotation=0)  # Keep labels horizontal

# Show the plot
plt.show()
# Out:
# <ipython-input-21-e191b343e008>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=worker_counts.index, y=worker_counts.values, palette="viridis")

# %%
# Pie Chart - Gender Ratio of Main Workers

plt.figure(figsize=(6,6))
gender_counts = df[['Main Workers - Total - Males', 'Main Workers - Total - Females']].sum()
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'pink'], startangle=90)
plt.ylabel("")
plt.title("Gender Ratio of Main Workers")
plt.show()

# %%
# Pie Chart - Gender Ratio of Marginal Workers

plt.figure(figsize=(6,6))
gender_counts = df[['Marginal Workers - Total - Males', 'Marginal Workers - Total - Females']].sum()
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'pink'], startangle=90)
plt.ylabel("")
plt.title("Gender Ratio of Marginal Workers")
plt.show()

# %%
# Pie Chart - Gender Ratio of Main Workers (Rural)

plt.figure(figsize=(6,6))
gender_counts = df[['Main Workers - Rural - Males', 'Main Workers - Rural - Females']].sum()
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['royalblue', 'orange'], startangle=90)
plt.ylabel("")
plt.title("Gender Ratio of Main Workers")
plt.show()

# %%
# Pie Chart - Gender Ratio of Main Workers (Urban)

plt.figure(figsize=(6,6))
gender_counts = df[['Main Workers - Urban - Males', 'Main Workers - Urban - Females']].sum()
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['teal', 'gold'], startangle=90)
plt.ylabel("")
plt.title("Gender Ratio of Main Workers")
plt.show()

# %%
# Rural vs. Urban Worker Distribution (Main)

plt.figure(figsize=(6,6))
rural_urban_counts = df[['Main Workers - Rural -  Persons', 'Main Workers - Urban -  Persons']].sum()
rural_urban_counts.plot(kind='pie', autopct='%1.1f%%', colors=['green', 'red'], startangle=90)
plt.ylabel("")
plt.title("Rural vs. Urban Worker Distribution")
plt.show()

# %%
# Rural vs. Urban Worker Distribution (Marginal)

plt.figure(figsize=(6,6))
rural_urban_counts = df[['Marginal Workers - Rural -  Persons', 'Marginal Workers - Urban -  Persons']].sum()
rural_urban_counts.plot(kind='pie', autopct='%1.1f%%', colors=['green', 'yellow'], startangle=90)
plt.ylabel("")
plt.title("Rural vs. Urban Worker Distribution")
plt.show()

# %%
# Rural Worker Distribution (Marginal Rural)

plt.figure(figsize=(6,6))
rural_urban_counts = df[['Marginal Workers - Rural - Males', 'Marginal Workers - Rural - Females']].sum()
rural_urban_counts.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'orange'], startangle=90)
plt.ylabel("")
plt.title("Rural Worker Distribution")
plt.show()

# %%
# Urban Worker Distribution (Marginal Urban)

plt.figure(figsize=(6,6))
rural_urban_counts = df[['Marginal Workers - Urban - Males', 'Marginal Workers - Urban - Females']].sum()
rural_urban_counts.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'yellow'], startangle=90)
plt.ylabel("")
plt.title("Urban Worker Distribution")
plt.show()

# %%
# Mapping state codes to state names
state_labels = {
    2: "Himachal Pradesh", 5: "Uttarakhand", 7: "Delhi", 8: "Rajasthan", 9: "Uttar Pradesh",
    10: "Bihar", 11: "Sikkim", 12: "Arunachal Pradesh", 13: "Nagaland", 14: "Manipur",
    15: "Mizoram", 16: "Tripura", 18: "Assam", 19: "West Bengal", 20: "Jharkhand",
    21: "Odisha", 24: "Gujarat", 27: "Maharashtra", 29: "Karnataka", 30: "Goa",
    32: "Kerala", 33: "Tamil Nadu", 34: "Puducherry"
}

# Extract relevant data without modifying df
df_temp = df[df['State Code'].isin(state_labels.keys())]

# Grouping data by 'State Code' and summing worker categories
state_wise_workers = df_temp.groupby('State Code')[[
    'Main Workers - Total -  Persons',
    'Marginal Workers - Total -  Persons'
]].sum()

# Creating an array of positions for bars
x = np.arange(len(state_wise_workers))

# Bar width
bar_width = 0.4

# Plot bars side-by-side
plt.figure(figsize=(12, 6))
plt.bar(x - bar_width/2, state_wise_workers['Main Workers - Total -  Persons'],
        width=bar_width, label='Main Workers', color='royalblue')
plt.bar(x + bar_width/2, state_wise_workers['Marginal Workers - Total -  Persons'],
        width=bar_width, label='Marginal Workers', color='orange')

# Updating x-axis labels with state names
plt.xticks(x, [state_labels[code] for code in state_wise_workers.index], rotation=90)

# Customizing the plot
plt.title("Number of Workers by State and Work Category")
plt.ylabel("Number of Workers")
plt.xlabel("States")
plt.legend(title="Work Category")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
df
# Out:
#         State Code  District Code  Division  Group  Class  \
# 1               18              0         1      0      0
# 2               18              0         1     11      0
# 3               18              0         1     11    111
# 4               18              0         1     11    112
# 5               18              0         1     11    113
# ...            ...            ...       ...    ...    ...
# 195140          15            288        99      0      0
# 195141          15            288        99    991      0
# 195142          15            288        99    991   9910
# 195143          15            288        99    992      0
# 195144          15            288        99    992   9920
#
#                                                  NIC Name  \
# 1       Crop and animal production, hunting and relate...
# 2                          Growing of non-perennial crops
# 3       Growing of cereals (except rice), leguminous c...
# ...

# %% [markdown]
# #Embedded clustering

# %%
# Embedded clustering

# !pip install umap-learn sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer

# Load Pre-trained Sentence Transformer Model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Handle missing values & reset index
df = df.dropna(subset=["NIC Name"]).reset_index(drop=True)

# Convert "NIC Name" to Dense Embeddings
embeddings = model.encode(df["NIC Name"].astype(str), convert_to_numpy=True)

# Convert to DataFrame
embeddings_df = pd.DataFrame(embeddings)
print("Shape of Embeddings:", embeddings_df.shape)  # Check dimensions
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %% [markdown]
# #PCA Dimension Reduction

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95)  # Keep 95% variance
final_features_pca = pca.fit_transform(embeddings)
print("✅ Shape after PCA:", final_features_pca.shape)
print(f"🔹 Explained Variance Ratio: {sum(pca.explained_variance_ratio_):.4f}")
# Out:
# ✅ Shape after PCA: (194651, 133)
# 🔹 Explained Variance Ratio: 0.9505

# %% [markdown]
# # UMAP Dimension Reduction

# %%
import umap

# UMAP dimensionality reduction
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=15, random_state=42)
final_features_umap = umap_model.fit_transform(embeddings)

print("✅ Shape after UMAP:", final_features_umap.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Shape after UMAP: (194651, 15)

# %% [markdown]
# ## K-Means

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# Use Elbow Method to find the optimal k
model = KMeans(init="k-means++", random_state=42)
visualizer = KElbowVisualizer(model, k=(2, 20), metric='distortion', timings=False)
visualizer.fit(final_features_umap)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# K-Means

# %%
# Apply K-Means with the optimal k
optimal_k = 14  # Replace with your best k from the elbow method
kmeans = KMeans(n_clusters=optimal_k, init="k-means++", random_state=42)
df["Cluster"] = kmeans.fit_predict(final_features_umap)

# Check cluster distribution
print(df["Cluster"].value_counts())
# Out:
# Cluster
# 10    19359
# 11    19019
# 9     17371
# 5     15952
# 6     15466
# 4     15172
# 12    13414
# 13    12963
# 3     12246
# 2     11430
# 7     11193
# 0     11185
# 8     10161
# 1      9720
# Name: count, dtype: int64

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

sil_score = silhouette_score(final_features_umap, df["Cluster"])
db_index = davies_bouldin_score(final_features_umap, df["Cluster"])

print(f"🔹 Silhouette Score: {sil_score:.4f}")
print(f"🔹 Davies-Bouldin Index: {db_index:.4f}")
# Out:
# 🔹 Silhouette Score: 0.2094
# 🔹 Davies-Bouldin Index: 1.6548

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Apply DBSCAN
dbscan = DBSCAN(eps=0.4, min_samples=300)  # You can tune eps & min_samples
df["Cluster_DBSCAN"] = dbscan.fit_predict(final_features_umap)

# Filter out noise points (-1 label)
valid_clusters = df[df["Cluster_DBSCAN"] != -1]["Cluster_DBSCAN"]

# Evaluate DBSCAN (only if valid clusters exist)
if len(set(valid_clusters)) > 1:
    sil_score_dbscan = silhouette_score(final_features_umap[df["Cluster_DBSCAN"] != -1], valid_clusters)
    db_index_dbscan = davies_bouldin_score(final_features_umap[df["Cluster_DBSCAN"] != -1], valid_clusters)
else:
    sil_score_dbscan = "Not Available (Too many outliers)"
    db_index_dbscan = "Not Available (Too many outliers)"

print(f"🔹 DBSCAN: Silhouette Score = {sil_score_dbscan}, Davies-Bouldin Index = {db_index_dbscan}")
# Out:
# 🔹 DBSCAN: Silhouette Score = 0.9894280433654785, Davies-Bouldin Index = 0.01380408315687475

# %% [markdown]
# # Grouping the clustering

# %%
# Exclude noise label -1
unique_clusters = df[df["Cluster_DBSCAN"] != -1]["Cluster_DBSCAN"].nunique()
print(f"✅ Number of valid clusters (excluding noise): {unique_clusters}")

# Optional: Show distribution
print(df["Cluster_DBSCAN"].value_counts())
# Out:
# ✅ Number of valid clusters (excluding noise): 284
# Cluster_DBSCAN
# -1      61897
#  102     2364
#  268     1308
#  88      1239
#  207      986
#         ...
#  8        302
#  242      302
#  11       302
#  262      301
#  74       300
# Name: count, Length: 285, dtype: int64

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Prepare valid DBSCAN clusters
df_valid = df[df["Cluster_DBSCAN"] != -1]

# Compute centroids of valid DBSCAN clusters
cluster_embeddings = []
for cluster_id in sorted(df_valid["Cluster_DBSCAN"].unique()):
    indices = df_valid[df_valid["Cluster_DBSCAN"] == cluster_id].index
    cluster_embeddings.append(np.mean(final_features_umap[indices], axis=0))

cluster_embeddings = np.array(cluster_embeddings)

# Silhouette Score method to find best K
scores = []
cluster_range = range(5, 50, 5)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(cluster_embeddings)
    score = silhouette_score(cluster_embeddings, labels)
    scores.append(score)

# Plot the scores
plt.figure(figsize=(10, 5))
plt.plot(cluster_range, scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different K')
plt.grid(True)
plt.show()

# Get the best k
best_k = cluster_range[np.argmax(scores)]
print(f"✅ Optimal number of macro clusters based on silhouette score: {best_k}")
# Out:
# ✅ Optimal number of macro clusters based on silhouette score: 25

# %%
# Cluster the clusters using optimal k
kmeans = KMeans(n_clusters=best_k, random_state=42)
meta_clusters = kmeans.fit_predict(cluster_embeddings)

# Map cluster ID to macro cluster ID
cluster_id_to_group = dict(zip(sorted(df_valid["Cluster_DBSCAN"].unique()), meta_clusters))
df["MacroCluster"] = df["Cluster_DBSCAN"].map(cluster_id_to_group)

print("✅ Number of Macro Clusters:", df["MacroCluster"].nunique())
# Out:
# ✅ Number of Macro Clusters: 25

# %%
# Extracting the Industry group of each cluster

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def get_lda_keywords(texts, n_topics=1, n_words=10):
    vectorizer = CountVectorizer(stop_words='english')
    X = vectorizer.fit_transform(texts)

    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda.fit(X)

    keywords = []
    for topic_idx, topic in enumerate(lda.components_):
        top_keywords = [vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-n_words - 1:-1]]
        keywords.append(top_keywords)
    return keywords[0]

# Prepare results dictionary
cluster_keywords = {}

# Loop over each Macro Cluster
for cluster_id in sorted(df['MacroCluster'].unique()):
    cluster_texts = df[df['MacroCluster'] == cluster_id]['NIC Name'].astype(str)

    if not cluster_texts.empty:
        keywords = get_lda_keywords(cluster_texts.tolist(), n_topics=1, n_words=10)
        cluster_keywords[cluster_id] = keywords
        print(f"Cluster {cluster_id}: {', '.join(keywords)}")
# Out:
# Cluster 12.0: activities, forestry, crop, support, non, vegetables, processing, fruit, preserving, crops
# Cluster 0.0: construction, buildings, projects, activities, engineering, civil, installation, roads, railways, specialized
# Cluster 1.0: activities, organizations, security, legal, private, membership, extraterritorial, bodies, general, public
# Cluster 2.0: raising, fishing, meat, processing, preserving, production, animal, cattle, buffaloes, sheep
# Cluster 3.0: collection, treatment, activities, water, supply, preparation, waste, storage, warehousing, logging
# Cluster 4.0: retail, sale, stores, specialized, markets, stalls, goods, food, tobacco, beverages
# Cluster 5.0: manufacture, equipment, transport, locomotives, rolling, stock, railway, transportation, support, warehousing
# Cluster 6.0: activities, service, support, office, business, personal, information, administrative, printing, systems
# ...

# %%
df = df[df["MacroCluster"].notna()]

# %%
# Mapping dictionary with single-word business categories
cluster_business_map = {
    0.0: "Construction",
    1.0: "Administration",
    2.0: "Livestock",
    3.0: "Utilities",
    4.0: "Retail",
    5.0: "Transport",
    6.0: "BusinessServices",
    7.0: "PublicServices",
    8.0: "Manufacturing",
    9.0: "Healthcare",
    10.0: "Metalwork",
    11.0: "Hospitality",
    12.0: "Agriculture",
    13.0: "Logistics",
    14.0: "Textiles",
    15.0: "Finance",
    16.0: "Mining",
    17.0: "Technology",
    18.0: "Wholesale",
    19.0: "Repairs",
    20.0: "Automotive",
    21.0: "Woodwork",
    22.0: "Electronics",
    23.0: "DomesticWork",
    24.0: "Education"
}

# Overwrite or create a new column with updated values
df["IndustryGroup"] = df["MacroCluster"].map(cluster_business_map)

# Preview the updated mapping
df[["MacroCluster", "IndustryGroup"]].drop_duplicates().sort_values("MacroCluster")
# Out:
#      MacroCluster     IndustryGroup
# 142           0.0      Construction
# 264           1.0    Administration
# 5             2.0         Livestock
# 79            3.0         Utilities
# 184           4.0            Retail
# 54            5.0         Transport
# 74            6.0  BusinessServices
# 256           7.0    PublicServices
# 34            8.0     Manufacturing
# 238           9.0        Healthcare
# 39           10.0         Metalwork
# 222          11.0       Hospitality
# 0            12.0       Agriculture
# 209          13.0         Logistics
# 50           14.0          Textiles
# 255          15.0           Finance
# 14           16.0            Mining
# 128          17.0        Technology
# 75           18.0         Wholesale
# 125          19.0           Repairs
# 161          20.0        Automotive
# 61           21.0          Woodwork
# 97           22.0       Electronics
# 228          23.0      DomesticWork
# 315          24.0         Education

# %%
# Save the df to a csv file

df.to_csv('Industrial_classification.csv', index=False)

# %%
# Read the file

df = pd.read_csv('/content/Industrial_classification.csv')

# %% [markdown]
# # Visualization

# %%
import plotly.express as px

# Calculate total workers per IndustryGroup
df["Total Workers"] = df["Main Workers - Total -  Persons"] + df["Marginal Workers - Total -  Persons"]

industry_summary = df.groupby("IndustryGroup")["Total Workers"].sum().reset_index().sort_values(by="Total Workers", ascending=False)
industry_summary.head()
# Out:
#    IndustryGroup  Total Workers
# 4   Construction       47742712
# 18        Retail       18951403
# 20      Textiles       17160797
# 12     Logistics       16129519
# 6      Education       13913284

# %%
# Plotly Bar Chart

fig = px.bar(
    industry_summary,
    x="IndustryGroup",
    y="Total Workers",
    color="IndustryGroup",
    title="Total Workers by Industry Group",
    labels={"Total Workers": "Number of Workers"},
    height=700
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Urban vs Rural Workers in each Industry

# Calculate total Urban and Rural Workers (Main + Marginal)
df["Total Urban Workers"] = df["Main Workers - Urban -  Persons"] + df["Marginal Workers - Urban -  Persons"]
df["Total Rural Workers"] = df["Main Workers - Rural -  Persons"] + df["Marginal Workers - Rural -  Persons"]

# Group by IndustryGroup
urban_rural_by_industry = df.groupby("IndustryGroup")[["Total Urban Workers", "Total Rural Workers"]].sum().reset_index()
urban_rural_by_industry = urban_rural_by_industry.sort_values(by="Total Urban Workers", ascending=False)

# %%
fig = px.bar(
    urban_rural_by_industry.melt(id_vars="IndustryGroup", value_vars=["Total Urban Workers", "Total Rural Workers"]),
    x="IndustryGroup",
    y="value",
    color="variable",
    barmode="group",
    title="Urban vs Rural Workers per Industry Group",
    labels={"value": "Number of Workers", "variable": "Worker Type"},
    height=700
)
fig.update_layout(xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Main vs Marginal workers distribution in each Industry

# Group by IndustryGroup
main_marginal_by_industry = df.groupby("IndustryGroup")[[
    "Main Workers - Total -  Persons",
    "Marginal Workers - Total -  Persons"
]].sum().reset_index()

main_marginal_by_industry = main_marginal_by_industry.sort_values(by="Main Workers - Total -  Persons", ascending=False)

# Rename columns for better visualization
main_marginal_by_industry.columns = ["IndustryGroup", "Main Workers", "Marginal Workers"]

# %%
fig = px.bar(
    main_marginal_by_industry.melt(id_vars="IndustryGroup", var_name="Worker Type", value_name="Count"),
    x="IndustryGroup",
    y="Count",
    color="Worker Type",
    barmode="group",
    title="Main vs Marginal Workers per Industry Group",
    labels={"IndustryGroup": "Industry Group", "Count": "Number of Workers"},
    height=700
)
fig.update_layout(xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Male vs Female Distribution in Industry

# Group by IndustryGroup
gender_distribution = df.groupby("IndustryGroup")[[
    "Main Workers - Total - Males",
    "Main Workers - Total - Females",
    "Marginal Workers - Total - Males",
    "Marginal Workers - Total - Females"
]].sum().reset_index()

gender_distribution = gender_distribution.sort_values(by="Main Workers - Total - Males", ascending=False)

# Optional: Rename for clarity
gender_distribution.columns = [
    "IndustryGroup", "Main Males", "Main Females", "Marginal Males", "Marginal Females"
]

# %%
# Visualization for Main workers

# Melt for Plotly
main_gender = gender_distribution[["IndustryGroup", "Main Males", "Main Females"]]
main_melt = main_gender.melt(id_vars="IndustryGroup", var_name="Gender", value_name="Count")

fig_main = px.bar(
    main_melt,
    x="IndustryGroup",
    y="Count",
    color="Gender",
    barmode="group",
    title="Main Workers: Males vs Females per Industry Group",
    height=700
)
fig_main.update_layout(xaxis_tickangle=-45)
fig_main.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Visualization for Marginal workers

# Melt for Plotly
marginal_gender = gender_distribution[["IndustryGroup", "Marginal Males", "Marginal Females"]]
marginal_melt = marginal_gender.melt(id_vars="IndustryGroup", var_name="Gender", value_name="Count")

fig_marginal = px.bar(
    marginal_melt,
    x="IndustryGroup",
    y="Count",
    color="Gender",
    barmode="group",
    title="Marginal Workers: Males vs Females per Industry Group",
    height=700
)
fig_marginal.update_layout(xaxis_tickangle=-45)
fig_marginal.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Streamlit App

# %%
# !pip install streamlit pandas plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

code = '''
import streamlit as st
import pandas as pd
import plotly.express as px

# --- Custom CSS ---
st.markdown("""
    <style>
        h2 {
            font-size: 18px !important;
            color: #380835 !important;
        }
        .main-title {
            font-size: 36px !important;
            font-weight: bold;
            text-align: center;
            margin-bottom: 20px;
            color: #0D47A1;
        }
    </style>
""", unsafe_allow_html=True)

# --- Dashboard Title ---
st.markdown('<p class="main-title">Workforce Distribution Dashboard</p>', unsafe_allow_html=True)
st.markdown("<br>", unsafe_allow_html=True)

# --- State Mapping ---
state_labels = {
    2: "Himachal Pradesh", 5: "Uttarakhand", 7: "Delhi", 8: "Rajasthan", 9: "Uttar Pradesh",
    10: "Bihar", 11: "Sikkim", 12: "Arunachal Pradesh", 13: "Nagaland", 14: "Manipur",
    15: "Mizoram", 16: "Tripura", 18: "Assam", 19: "West Bengal", 20: "Jharkhand",
    21: "Odisha", 24: "Gujarat", 27: "Maharashtra", 29: "Karnataka", 30: "Goa",
    32: "Kerala", 33: "Tamil Nadu", 34: "Puducherry"
}

# --- Load Data ---
@st.cache_data
def load_data():
    df = pd.read_csv("Industrial_classification.csv")
    df["State Name"] = df["State Code"].map(state_labels)
    df["Total Workers"] = df["Main Workers - Total -  Persons"] + df["Marginal Workers - Total -  Persons"]
    return df

df = load_data()

# --- Sidebar Filters ---
st.sidebar.header("🔍 Filter Data")

selected_states = st.sidebar.multiselect("Select State(s)", df["State Name"].dropna().unique())
filtered_districts = df[df["State Name"].isin(selected_states)]["District Name"].dropna().unique() if selected_states else []
selected_districts = st.sidebar.multiselect("Select District(s)", options=filtered_districts)

# ✅ Worker Type (Main/Marginal)
worker_type = st.sidebar.radio("Select Worker Type", ["Main", "Marginal"])

# ✅ Gender (with "Both" option)
gender = st.sidebar.radio("Select Gender", ["Males", "Females", "Males & Females"])

# ✅ IndustryGroup
industry_options = df["IndustryGroup"].dropna().unique()
selected_industries = st.sidebar.multiselect("Select Industry Group(s)", industry_options, default=[])

# --- Compute column(s) based on gender selection ---
if gender == "Males & Females":
    col_male = f"{worker_type} Workers - Total - Males"
    col_female = f"{worker_type} Workers - Total - Females"
    df["Combined_Workers"] = df[col_male] + df[col_female]
    col_name = "Combined_Workers"
else:
    col_name = f"{worker_type} Workers - Total - {gender}"


# --- Filtered Data ---
if selected_states and selected_districts and selected_industries:
    filtered_df = df[
        (df["State Name"].isin(selected_states)) &
        (df["District Name"].isin(selected_districts)) &
        (df["IndustryGroup"].isin(selected_industries))
    ]
else:
    filtered_df = pd.DataFrame()

# --- Visualizations ---
if not filtered_df.empty:
    st.subheader("📊 Industry-wise Worker Distribution")

    industry_chart = px.bar(
        filtered_df.groupby("IndustryGroup")[col_name].sum().reset_index(),
        x="IndustryGroup",
        y=col_name,
        color="IndustryGroup",
        title=f"Total {worker_type} Workers ({gender}) per Industry",
    )
    st.plotly_chart(industry_chart)

    # --- District-wise Summary ---
    district_summary = filtered_df.groupby("District Name")[col_name].sum().reset_index()

    if not district_summary.empty:
        st.subheader("📊 District-wise Worker Distribution")
        district_chart = px.bar(
            district_summary,
            x="District Name",
            y=col_name,
            color=col_name,
            title=f"{worker_type} Workers ({gender}) per District",
        )
        st.plotly_chart(district_chart)

    # --- Pie Chart: State-wise Summary ---
    state_summary = filtered_df.groupby("State Name")[col_name].sum().reset_index()
    if not state_summary.empty:
        st.subheader("🥧 State-wise Worker Distribution")
        pie_chart = px.pie(
            state_summary,
            names="State Name",
            values=col_name,
            title=f"Share of {worker_type} Workers ({gender}) Across States",
            hole=0.4
        )
        st.plotly_chart(pie_chart)

else:
    st.markdown("""
        <marquee style="color:red; font-size:18px;">
        ⚠️ Please select at least one State, District, and Industry Group to see the data.
        </marquee>
    """, unsafe_allow_html=True)

'''

with open("app_final.py", "w") as f:
    f.write(code)

files.download("app_final.py")  # This will download the file
